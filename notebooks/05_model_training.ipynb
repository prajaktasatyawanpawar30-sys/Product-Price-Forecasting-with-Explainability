# %% [markdown]
# # 05 - Model Training
# ## Product Price Forecasting with Explainability
#
# ### Objective:
# Train and compare multiple regression models (Linear Regression, Ridge, Random Forest, Gradient Boosting, XGBoost), select the top-performing model, and save model artifacts.

# %%
import sys
sys.path.append('..')
import json
from src.train_model import ModelTrainer

# Instantiate ModelTrainer
trainer = ModelTrainer()
results = trainer.train_and_evaluate(test_size=0.2)

# %%
print('Best Model Identified:', trainer.best_model_name)
print('Comparison Summary:')
import pandas as pd
pd.DataFrame(results).T
